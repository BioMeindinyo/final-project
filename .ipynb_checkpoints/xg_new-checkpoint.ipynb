# %% [markdown]
# Import libraries

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import optuna
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import shap
from lime.lime_tabular import LimeTabularExplainer
import time

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv('Telco_customer_churn.csv')
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label Churn Value Churn Score  CLTV                   Churn Reason
# 0         Yes           1          86  3239   Competitor made better offer
# 1         Yes           1          67  2701                          Moved
# 2         Yes           1          86  5372                          Moved
# 3         Yes           1          84  5003                          Moved
# 4         Yes           1          89  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %% [markdown]
# EDA - Check for and handle missing values

# %%
df.loc[(df['Total Charges'] == ' '), 'Total Charges'] = 0
df['Total Charges'] = pd.to_numeric(df['Total Charges'])
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Label           object
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# Churn Reason          object
# dtype: object

# %% [markdown]
# Data preprocessing and dropping non-essential columns

# %%
df.drop(['CustomerID', 'State', 'Country', 'Count', 'Lat Long', 'Churn Label', 'Churn Score', 'CLTV', 'Churn Reason'], axis=1, inplace=True)

# %% [markdown]
# Replace white spaces with underscores

# %%
df.columns = df.columns.str.replace(' ', '_')
df.replace(' ', '_', regex=True, inplace=True)

# %% [markdown]
# Prepare features and target

# %%
X = df.drop('Churn_Value', axis=1).copy()
y = df['Churn_Value'].copy()

# %% [markdown]
#  One-hot encoding

# %%
X_encoded = pd.get_dummies(X, columns=[
    'City', 'Gender', 'Senior_Citizen', 'Partner', 'Dependents', 
    'Phone_Service', 'Multiple_Lines', 'Internet_Service',
    'Online_Security', 'Online_Backup', 'Device_Protection',
    'Tech_Support', 'Streaming_TV', 'Streaming_Movies',
    'Contract', 'Paperless_Billing', 'Payment_Method'
])

# %% [markdown]
# Split into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# Define the Optuna objective function

# %%
def objective(trial):
    smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
    smote_k_neighbors = trial.suggest_int("k_neighbors", 3, 10)
    
    xgb_n_estimators = trial.suggest_int("n_estimators", 50, 300)
    xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
    xgb_max_depth = trial.suggest_int("max_depth", 3, 20)
    xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
    xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
    
    smote = SMOTE(sampling_strategy=smote_sampling_strategy, k_neighbors=smote_k_neighbors, random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
    
    xgb_model = XGBClassifier(
        n_estimators=xgb_n_estimators,
        learning_rate=xgb_learning_rate,
        max_depth=xgb_max_depth,
        subsample=xgb_subsample,
        colsample_bytree=xgb_colsample_bytree,
        random_state=42,
        eval_metric='logloss'
    )
    xgb_model.fit(X_train_resampled, y_train_resampled)
    y_pred = xgb_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %% [markdown]
# Run the Optuna study

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best parameters:", study.best_params)
# Out:
# [I 2025-01-14 15:16:16,275] A new study created in memory with name: no-name-2509f39f-d838-4b2a-8ca7-dd62a6630276
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:16:20,835] Trial 0 finished with value: 0.7934705464868701 and parameters: {'sampling_strategy': 0.9289286637265602, 'k_neighbors': 8, 'n_estimators': 281, 'learning_rate': 0.07086021227405134, 'max_depth': 3, 'subsample': 0.7133131134418179, 'colsample_bytree': 0.8688769118714237}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:16:28,730] Trial 1 finished with value: 0.7806955287437899 and parameters: {'sampling_strategy': 0.9749342285899137, 'k_neighbors': 5, 'n_estimators': 240, 'learning_rate': 0.04016287394608742, 'max_depth': 12, 'subsample': 0.7103781733196, 'colsample_bytree': 0.8777960334820611}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:16:35,582] Trial 2 finished with value: 0.7849538679914834 and parameters: {'sampling_strategy': 0.8984302815403049, 'k_neighbors': 9, 'n_estimators': 116, 'learning_rate': 0.14286251467494124, 'max_depth': 14, 'subsample': 0.7249901139076179, 'colsample_bytree': 0.6455940433673899}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:16:42,461] Trial 3 finished with value: 0.7821149751596878 and parameters: {'sampling_strategy': 0.6935784072297853, 'k_neighbors': 9, 'n_estimators': 293, 'learning_rate': 0.173126953321978, 'max_depth': 4, 'subsample': 0.6336220433665308, 'colsample_bytree': 0.977816278771813}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:16:55,119] Trial 4 finished with value: 0.7842441447835344 and parameters: {'sampling_strategy': 0.62774546607069, 'k_neighbors': 9, 'n_estimators': 220, 'learning_rate': 0.05872428312687076, 'max_depth': 18, 'subsample': 0.9456183922285191, 'colsample_bytree': 0.8737301858068407}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:17:01,834] Trial 5 finished with value: 0.7892122072391767 and parameters: {'sampling_strategy': 0.8992310353389701, 'k_neighbors': 5, 'n_estimators': 105, 'learning_rate': 0.030924733226992806, 'max_depth': 11, 'subsample': 0.9492464882099637, 'colsample_bytree': 0.9940814544850802}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:17:11,808] Trial 6 finished with value: 0.7892122072391767 and parameters: {'sampling_strategy': 0.8854167682537455, 'k_neighbors': 3, 'n_estimators': 153, 'learning_rate': 0.045054959967286444, 'max_depth': 20, 'subsample': 0.7115496169366902, 'colsample_bytree': 0.6609170893157883}. Best is trial 0 with value: 0.7934705464868701.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15

# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:19:20,626] Trial 26 finished with value: 0.7955997161107168 and parameters: {'sampling_strategy': 0.848023606817166, 'k_neighbors': 6, 'n_estimators': 183, 'learning_rate': 0.02031619705848148, 'max_depth': 13, 'subsample': 0.7612855626648722, 'colsample_bytree': 0.7578423533644065}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:19:30,542] Trial 27 finished with value: 0.794889992902768 and parameters: {'sampling_strategy': 0.9402184970020948, 'k_neighbors': 7, 'n_estimators': 202, 'learning_rate': 0.014458942332675103, 'max_depth': 16, 'subsample': 0.6697916657437346, 'colsample_bytree': 0.8218610007003632}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# ...
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:17,371] Trial 40 finished with value: 0.7955997161107168 and parameters: {'sampling_strategy': 0.9263152108832295, 'k_neighbors': 8, 'n_estimators': 108, 'learning_rate': 0.04294011994179792, 'max_depth': 13, 'subsample': 0.6947685240279109, 'colsample_bytree': 0.8865786627727681}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:25,041] Trial 41 finished with value: 0.801277501774308 and parameters: {'sampling_strategy': 0.7478396683652089, 'k_neighbors': 7, 'n_estimators': 165, 'learning_rate': 0.01018634670423965, 'max_depth': 11, 'subsample': 0.789590065184028, 'colsample_bytree': 0.7834006611873994}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:31,860] Trial 42 finished with value: 0.7977288857345636 and parameters: {'sampling_strategy': 0.761441969785533, 'k_neighbors': 9, 'n_estimators': 161, 'learning_rate': 0.012621795942785211, 'max_depth': 10, 'subsample': 0.7798705002290035, 'colsample_bytree': 0.7734750451312716}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:41,237] Trial 43 finished with value: 0.7963094393186657 and parameters: {'sampling_strategy': 0.7124023564320703, 'k_neighbors': 7, 'n_estimators': 197, 'learning_rate': 0.011846610152288748, 'max_depth': 12, 'subsample': 0.7300283519630655, 'colsample_bytree': 0.7898153208904619}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:48,673] Trial 44 finished with value: 0.801277501774308 and parameters: {'sampling_strategy': 0.8061530905514138, 'k_neighbors': 8, 'n_estimators': 136, 'learning_rate': 0.015238410988401828, 'max_depth': 14, 'subsample': 0.7934838453469772, 'colsample_bytree': 0.742801296420944}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:53,976] Trial 45 finished with value: 0.7970191625266146 and parameters: {'sampling_strategy': 0.7577473788818903, 'k_neighbors': 9, 'n_estimators': 122, 'learning_rate': 0.016353301025565845, 'max_depth': 9, 'subsample': 0.7867752367807201, 'colsample_bytree': 0.7036426670666803}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:21:58,516] Trial 46 finished with value: 0.7842441447835344 and parameters: {'sampling_strategy': 0.7946660903370987, 'k_neighbors': 8, 'n_estimators': 99, 'learning_rate': 0.08972643741037728, 'max_depth': 11, 'subsample': 0.8163241639784183, 'colsample_bytree': 0.6322838411197018}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:22:06,680] Trial 47 finished with value: 0.7927608232789212 and parameters: {'sampling_strategy': 0.6629287056872668, 'k_neighbors': 5, 'n_estimators': 161, 'learning_rate': 0.02132012089179161, 'max_depth': 14, 'subsample': 0.7682784876630335, 'colsample_bytree': 0.7408601614344285}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:22:11,269] Trial 48 finished with value: 0.7913413768630234 and parameters: {'sampling_strategy': 0.6182762091833396, 'k_neighbors': 10, 'n_estimators': 187, 'learning_rate': 0.014518331039470764, 'max_depth': 3, 'subsample': 0.7434536145736721, 'colsample_bytree': 0.6795210850467115}. Best is trial 25 with value: 0.8019872249822569.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   xgb_learning_rate = trial.suggest_loguniform("learning_rate", 0.01, 0.3)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_subsample = trial.suggest_uniform("subsample", 0.6, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\3686163521.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   xgb_colsample_bytree = trial.suggest_uniform("colsample_bytree", 0.6, 1.0)
# [I 2025-01-14 15:22:20,720] Trial 49 finished with value: 0.794889992902768 and parameters: {'sampling_strategy': 0.7207808385407147, 'k_neighbors': 6, 'n_estimators': 209, 'learning_rate': 0.012457159818481235, 'max_depth': 12, 'subsample': 0.7976722522813096, 'colsample_bytree': 0.7227163727095881}. Best is trial 25 with value: 0.8019872249822569.
# Best parameters: {'sampling_strategy': 0.8536176465594532, 'k_neighbors': 6, 'n_estimators': 183, 'learning_rate': 0.014091842595230886, 'max_depth': 13, 'subsample': 0.7510702511586398, 'colsample_bytree': 0.7574647114519422}

# %% [markdown]
#  Apply SMOTE with best parameters

# %%
best_smote = SMOTE(sampling_strategy=study.best_params["sampling_strategy"], k_neighbors=study.best_params["k_neighbors"], random_state=42)
X_train_best, y_train_best = best_smote.fit_resample(X_train, y_train)

# %%
# Train final XGBoost model
best_xgb_model = XGBClassifier(
    n_estimators=study.best_params["n_estimators"],
    learning_rate=study.best_params["learning_rate"],
    max_depth=study.best_params["max_depth"],
    subsample=study.best_params["subsample"],
    colsample_bytree=study.best_params["colsample_bytree"],
    random_state=42,
    eval_metric='logloss'
)
best_xgb_model.fit(X_train_best, y_train_best)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7574647114519422, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.014091842595230886,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=13, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=183, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
#  Evaluate the model

# %%
y_pred_best = best_xgb_model.predict(X_test)
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_best))
print("\nClassification Report:\n", classification_report(y_test, y_pred_best))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred_best))
# Out:
# Confusion Matrix:
#  [[908 127]
#  [152 222]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      1035
#            1       0.64      0.59      0.61       374
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.74      0.74      1409
# weighted avg       0.80      0.80      0.80      1409
#
#
# Accuracy Score: 0.8019872249822569

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Define the Optuna objective function
def objective(trial):
    smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
    smote_k_neighbors = trial.suggest_int("k_neighbors", 3, 10)
    
    svm_C = trial.suggest_loguniform("C", 0.1, 10)
    svm_kernel = trial.suggest_categorical("kernel", ["linear", "rbf"])
    
    smote = SMOTE(sampling_strategy=smote_sampling_strategy, k_neighbors=smote_k_neighbors, random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
    
    svm_model = SVC(C=svm_C, kernel=svm_kernel, probability=True, random_state=42, class_weight='balanced')
    svm_model.fit(X_train_resampled, y_train_resampled)
    y_pred = svm_model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    return accuracy

# %%
# Run the Optuna study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print("Best parameters:", study.best_params)
# Out:
# [I 2025-01-14 15:23:33,561] A new study created in memory with name: no-name-be8fc9a8-1fc2-4b12-b1aa-29cf4b80f244
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:29:00,263] Trial 0 finished with value: 0.46983676366217175 and parameters: {'sampling_strategy': 0.7078369712803996, 'k_neighbors': 5, 'C': 1.841517701723231, 'kernel': 'rbf'}. Best is trial 0 with value: 0.46983676366217175.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:33:43,913] Trial 1 finished with value: 0.47338537970191624 and parameters: {'sampling_strategy': 0.5801626720996049, 'k_neighbors': 9, 'C': 6.201471467931814, 'kernel': 'rbf'}. Best is trial 1 with value: 0.47338537970191624.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:38:23,049] Trial 2 finished with value: 0.46770759403832507 and parameters: {'sampling_strategy': 0.5517754504546027, 'k_neighbors': 6, 'C': 1.4343040323195915, 'kernel': 'rbf'}. Best is trial 1 with value: 0.47338537970191624.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:45:50,138] Trial 3 finished with value: 0.46557842441447833 and parameters: {'sampling_strategy': 0.9843672017151118, 'k_neighbors': 5, 'C': 1.032122016178852, 'kernel': 'rbf'}. Best is trial 1 with value: 0.47338537970191624.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:49:21,750] Trial 4 finished with value: 0.7189496096522356 and parameters: {'sampling_strategy': 0.7329069363640315, 'k_neighbors': 5, 'C': 3.1428825314303155, 'kernel': 'linear'}. Best is trial 4 with value: 0.7189496096522356.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:54:54,290] Trial 5 finished with value: 0.29737402413058905 and parameters: {'sampling_strategy': 0.6428700839634967, 'k_neighbors': 6, 'C': 0.17757754226981462, 'kernel': 'rbf'}. Best is trial 4 with value: 0.7189496096522356.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
# [I 2025-01-14 15:58:28,568] Trial 6 finished with value: 0.716820440028389 and parameters: {'sampling_strategy': 0.6925518891076567, 'k_neighbors': 8, 'C': 2.4048842215203576, 'kernel': 'linear'}. Best is trial 4 with value: 0.7189496096522356.
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:3: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   smote_sampling_strategy = trial.suggest_uniform("sampling_strategy", 0.5, 1.0)
# C:\Users\USER\AppData\Local\Temp\ipykernel_16604\2400251756.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   svm_C = trial.suggest_loguniform("C", 0.1, 10)
